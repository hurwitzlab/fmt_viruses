# %% [markdown]
# # Assembling reads into contigs
#
# This notebook will go through the workflow for using the metaspades and megahit assembly tools. In this section we are going to assemble our reads into contigs. Contigs are fragments of DNA that represent parts of a genome. If you are lucky, you might even be able to assemble an entire genome in a single contig! But, most of the time, contigs are just part of a genome with missing fragments in between contigs that prevent you from assembling the entire genome.
#
# 1. An introduction to [Metaspades](https://cab.spbu.ru/files/release3.12.0/manual.html)

# %% [markdown]
# ## Getting Started
#
# You will need to rerun this section each time you come back to this notebook to reset all directories and variables.

# %%
# set the variables for your netid and xfile
netid = "kolodisner"
xfile = "xac"

# %%
# Go into the working directory
work_dir = "/xdisk/bhurwitz/virus_hunting/" + netid + "/04_assembly"
# %cd $work_dir
# Out:
# /xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly

# %% [markdown]
# ## Creating a config file
# The scripts below executes code that requires certain variables to be set. So we don't need to edit the code in the script, we are going to use a config file that defines all of these variables for us. Then when we want to use these variables in the script, we will "source" the config file to set the variables.

# %% [markdown]
# ### Data Management
#
# We'll be creating two assemblies based on the trimmed/human removed reads. Let's setup the output directories ahead of time.

# %%
# !mkdir $work_dir/out_spades

# %%
# create a config file with all of the variables you need
# notice that we will assemble the reads that are both trimmed and have human removed.
# !echo "export NETID=$netid" > config.sh
# !echo "export XFILE=$xfile" >> config.sh
# !echo "export XFILE_DIR=/xdisk/bhurwitz/virus_hunting/$netid" >> config.sh
# !echo "export FASTQ_DIR=/xdisk/bhurwitz/virus_hunting/$netid/03_contam_removal" >> config.sh
# !echo "export OUT_SPADES=/xdisk/bhurwitz/virus_hunting/$netid/04_assembly/out_spades" >> config.sh

# %%
# !cat config.sh
# Out:
# export NETID=kolodisner
# export XFILE=xac
# export XFILE_DIR=/xdisk/bhurwitz/virus_hunting/kolodisner
# export FASTQ_DIR=/xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal
# export OUT_SPADES=/xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly/out_spades

# %% [markdown]
# ## Step 1: Running Metaspades to create contigs
#
# You will be assembling your reads using a program called spades, that has the metaspades.py program within it for assembling metagenomes comprised of multiple organisms.
#
# It's important to note that this assembler is memory intensive, and for large files it takes a lot of resource and time. A common error for large files is running out of memory to complete the job in the HPC. If needed, we can modify our script if it requires more memory.
#
# Puma can have 94 CPUs @ 5gb/CPU <br>
# Ocelote can have 28 CPUs @ 6gb/CPU
#
# This [HPC documentation](https://public.confluence.arizona.edu/display/UAHPC/Running+Jobs+with+SLURM) is handy to have as you edit your scripts and use different HPCs within UA.

# %%
# Create a script to run metaspades
# A few important points:
# 1. We are using the variables from the config file via the `source ./config.sh` command in the script.
# 2. metaspades runs on each of the fastq files in the trimmed $FASTQ_DIR
# 3. The results will be written into our $OUT_SPADES directory
# 4. Notice that we are asking for alot more resource (28 cores and 5G of memory per core), we are also asking for more time (24 hours)
my_code = '''#!/bin/bash
#SBATCH --output=Job-spades-%a.out
#SBATCH --account=bhurwitz
#SBATCH --partition=standard
#SBATCH --nodes=1
#SBATCH --ntasks=1
#SBATCH --time=48:00:00
#SBATCH --cpus-per-task=28
#SBATCH --mem-per-cpu=5gb
#SBATCH --array=0-2

pwd; hostname; date

source ./config.sh
names=($(cat $XFILE_DIR/$XFILE))

SAMPLE_ID=${names[${SLURM_ARRAY_TASK_ID}]}

PAIR1=${FASTQ_DIR}/${SAMPLE_ID}_1.fastq*
PAIR2=${FASTQ_DIR}/${SAMPLE_ID}_2.fastq*

#add threads flag & exposition on adding threads or it runs inefficient
apptainer run /contrib/singularity/shared/bhurwitz/spades:3.15.5--h95f258a_1.sif metaspades.py \
   -o ${OUT_SPADES}/${names[${SLURM_ARRAY_TASK_ID}]} \
   --pe1-1 ${PAIR1} \
   --pe1-2 ${PAIR2}
'''

with open('run_metaspades.sh', mode='w') as file:
    file.write(my_code)

# %%
# you should be in your working directory when you run this script
# do you see your config.sh file, and the rrun_metaspades.sh script?
# !pwd
# !ls
# Out:
# /xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly
# config.sh  out_spades  run_metaspades.sh

# %%
# Let's run sbatch to run metaspades on each of the FASTQ files
# Remember that this may take a while to run, so take a break, 
# and get a coffee.
# !sbatch ./run_metaspades.sh
# Out:
# Submitted batch job 3036763

# %%
# You can check if it is running using the squeue command
# Check for all jobs under your netid
# !squeue --user=$netid
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#          3036763_0  standard run_meta kolodisn  R    9:11:03      1 i1n14
#          3036763_1  standard run_meta kolodisn  R    9:11:03      1 i4n15
#          3036763_2  standard run_meta kolodisn  R    9:11:03      1 i6n17
#            3040126  standard  jupyter kolodisn  R       3:53      1 i16n3

# %%
# Once your jobs have run (or are running) you can check the progress
# and also look for errors in the *out files
# For example, you can look at Job-spades-0.out
# !ls
# !cat Job-spades-0.out
# Out:
# Job-spades-0.out  Job-spades-2.out  out_spades
# Job-spades-1.out  config.sh	    run_metaspades.sh
# /xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly
# i1n14.ocelote.hpc.arizona.edu
# Sat Mar 30 12:58:20 MST 2024
# Command line: /usr/local/bin/metaspades.py	-o	/xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly/out_spades/ERR2198703	--pe1-1	/xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal/ERR2198703_1.fastq.gz	--pe1-2	/xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal/ERR2198703_2.fastq.gz
#
# System information:
#   SPAdes version: 3.15.5
#   Python version: 3.10.6
#   OS: Linux-3.10.0-1160.108.1.el7.x86_64-x86_64-with-glibc2.28
#
# Output dir: /xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly/out_spades/ERR2198703
# Mode: read error correction and assembling
# Debug mode is turned OFF
#
# Dataset parameters:
#   Metagenomic mode
#   Reads:
#     Library number: 1, library type: paired-end
#       orientation: fr
#       left reads: ['/xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal/ERR2198703_1.fastq.gz']
#       right reads: ['/xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal/ERR2198703_2.fastq.gz']
#       interlaced reads: not specified
#       single reads: not specified
#       merged reads: not specified
# Read error correction parameters:
#   Iterations: 1
#   PHRED offset will be auto-detected
#   Corrected reads will be compressed
# Assembly parameters:
#   k: [21, 33, 55]
#   Repeat resolution is enabled
#   Mismatch careful mode is turned OFF
#   MismatchCorrector will be SKIPPED
#   Coverage cutoff is turned OFF
# Other parameters:
#   Dir for temp files: /xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly/out_spades/ERR2198703/tmp
#   Threads: 16
#   Memory limit (in Gb): 188
#
#
# ======= SPAdes pipeline started. Log can be found here: /xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly/out_spades/ERR2198703/spades.log
#
# /xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal/ERR2198703_1.fastq.gz: max reads length: 101
# /xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal/ERR2198703_2.fastq.gz: max reads length: 101
#
# Reads length: 101
#
#
# ===== Before start started.
#
#
# ===== Read error correction started.
#
#
# ===== Read error correction started.
#
#
# == Running: /usr/local/bin/spades-hammer /xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly/out_spades/ERR2198703/corrected/configs/config.info
#
#   0:00:00.000     1M / 31M   INFO    General                 (main.cpp                  :  75)   Starting BayesHammer, built from N/A, git revision N/A
#   0:00:00.000     1M / 31M   INFO    General                 (main.cpp                  :  76)   Loading config from /xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly/out_spades/ERR2198703/corrected/configs/config.info
#   0:00:00.001     1M / 31M   INFO    General                 (main.cpp                  :  78)   Maximum # of threads to use (adjusted due to OMP capabilities): 1
#   0:00:00.001     1M / 31M   INFO    General                 (memory_limit.cpp          :  54)   Memory limit set to 188 Gb
#   0:00:00.001     1M / 31M   INFO    General                 (main.cpp                  :  86)   Trying to determine PHRED offset
#   0:00:00.002     1M / 31M   INFO    General                 (main.cpp                  :  92)   Determined value is 33
#   0:00:00.002     1M / 31M   INFO    General                 (hammer_tools.cpp          :  38)   Hamming graph threshold tau=1, k=21, subkmer positions = [ 0 10 ]
#   0:00:00.002     1M / 31M   INFO    General                 (main.cpp                  : 113)   Size of aux. kmer data 24 bytes
#      === ITERATION 0 begins ===
#   0:00:00.002     1M / 31M   INFO   K-mer Counting           (kmer_data.cpp             : 283)   Estimating k-mer count
#   0:00:00.006    17M / 31M   INFO   K-mer Counting           (kmer_data.cpp             : 288)   Processing /xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal/ERR2198703_1.fastq.gz
#   0:04:08.066    17M / 31M   INFO   K-mer Counting           (kmer_data.cpp             : 297)   Processed 24821021 reads
#   0:04:08.066    17M / 31M   INFO   K-mer Counting           (kmer_data.cpp             : 288)   Processing /xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal/ERR2198703_2.fastq.gz
#   0:08:10.860    17M / 31M   INFO   K-mer Counting           (kmer_data.cpp             : 297)   Processed 49642042 reads
#   0:08:10.860    17M / 31M   INFO   K-mer Counting           (kmer_data.cpp             : 302)   Total 49642042 reads processed
#   0:08:11.147    17M / 31M   INFO   K-mer Counting           (kmer_data.cpp             : 305)   Estimated 700819473 distinct kmers
#   0:08:11.147     1M / 31M   INFO   K-mer Counting           (kmer_data.cpp             : 309)   Filtering singleton k-mers
#   0:08:11.148  2599M / 2599M INFO   K-mer Counting           (kmer_data.cpp             : 315)   Processing /xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal/ERR2198703_1.fastq.gz
#   0:23:41.472  2599M / 2619M INFO   K-mer Counting           (kmer_data.cpp             : 324)   Processed 24821021 reads
#   0:23:41.472  2599M / 2619M INFO   K-mer Counting           (kmer_data.cpp             : 315)   Processing /xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal/ERR2198703_2.fastq.gz
#   0:39:11.950  2599M / 2619M INFO   K-mer Counting           (kmer_data.cpp             : 324)   Processed 49642042 reads
#   0:39:11.950  2599M / 2619M INFO   K-mer Counting           (kmer_data.cpp             : 329)   Total 49642042 reads processed
#   0:39:11.965  2599M / 2619M INFO    General                 (kmer_index_builder.hpp    : 243)   Splitting kmer instances into 16 files using 1 threads. This might take a while.
#   0:39:11.969  2599M / 2619M INFO    General                 (file_limit.hpp            :  42)   Open file limit set to 4096
#   0:39:11.969  2599M / 2619M INFO    General                 (kmer_splitter.hpp         :  93)   Memory available for splitting buffers: 61.8208 Gb
#   0:39:11.969  2599M / 2619M INFO    General                 (kmer_splitter.hpp         : 101)   Using cell size of 4194304
#   0:39:11.975  3175M / 3175M INFO   K-mer Splitting          (kmer_data.cpp             :  97)   Processing /xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal/ERR2198703_1.fastq.gz
#   0:39:34.313  3175M / 3199M INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 432358 reads
#   0:39:58.406  3175M / 3199M INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 870155 reads
#   0:40:22.465  3175M / 3201M INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 1305432 reads
#   0:40:46.456  3175M / 3203M INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 1738170 reads
#   0:41:10.534  3175M / 3205M INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 2176369 reads
#   0:41:34.490  3175M / 3223M INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 2613371 reads
#   0:41:58.556  3175M / 3223M INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 3045456 reads
#   0:43:09.054  3175M / 3227M INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 4358078 reads
#   0:46:54.257  3175M / 3229M INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 8721340 reads
#   0:54:12.577  3175M / 3235M INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 17170632 reads
#   1:01:10.577  3175M / 3235M INFO   K-mer Splitting          (kmer_data.cpp             :  97)   Processing /xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal/ERR2198703_2.fastq.gz
#   1:08:46.148  3175M / 3237M INFO   K-mer Splitting          (kmer_data.cpp             : 107)   Processed 33628867 reads
#   1:22:18.563  3175M / 3241M INFO   K-mer Splitting          (kmer_data.cpp             : 112)   Total 49642042 reads processed
#   1:22:18.564  2599M / 3241M INFO    General                 (kmer_index_builder.hpp    : 249)   Starting k-mer counting.
#   1:30:41.078  2599M / 5479M INFO    General                 (kmer_index_builder.hpp    : 260)   K-mer counting done. There are 431929926 kmers in total.
#   1:30:41.089     3M / 5479M INFO   K-mer Index Building     (kmer_index_builder.hpp    : 395)   Building perfect hash indices
#   1:32:11.418   310M / 5479M INFO   K-mer Index Building     (kmer_index_builder.hpp    : 431)   Index built. Total 431929926 kmers, 311979128 bytes occupied (5.77833 bits per kmer).
#   1:32:11.418   310M / 5479M INFO   K-mer Counting           (kmer_data.cpp             : 354)   Arranging kmers in hash map order
#   1:33:02.842  6902M / 7069M INFO    General                 (main.cpp                  : 148)   Clustering Hamming graph.
#   2:16:23.618  6902M / 7069M INFO    General                 (main.cpp                  : 155)   Extracting clusters:
#   2:16:23.618  6902M / 7069M INFO    General                 (concurrent_dsu.cpp        :  18)   Connecting to root
#   2:16:26.111  6902M / 7069M INFO    General                 (concurrent_dsu.cpp        :  34)   Calculating counts
#   2:18:12.751    16G / 16G   INFO    General                 (concurrent_dsu.cpp        :  63)   Writing down entries
#   2:19:52.788  6902M / 22G   INFO    General                 (main.cpp                  : 167)   Clustering done. Total clusters: 395743864
#   2:19:52.796  3606M / 22G   INFO   K-mer Counting           (kmer_data.cpp             : 371)   Collecting K-mer information, this takes a while.
#   2:19:55.326    14G / 22G   INFO   K-mer Counting           (kmer_data.cpp             : 377)   Processing /xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal/ERR2198703_1.fastq.gz
#   2:51:54.986    14G / 22G   INFO   K-mer Counting           (kmer_data.cpp             : 377)   Processing /xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal/ERR2198703_2.fastq.gz
#   3:23:13.650    14G / 22G   INFO   K-mer Counting           (kmer_data.cpp             : 384)   Collection done, postprocessing.
#   3:23:14.935    14G / 22G   INFO   K-mer Counting           (kmer_data.cpp             : 397)   There are 431929926 kmers in total. Among them 238766 (0.0552789%) are singletons.
#   3:23:14.935    14G / 22G   INFO    General                 (main.cpp                  : 173)   Subclustering Hamming graph
#   3:26:46.452    14G / 22G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 650)   Subclustering done. Total 917 non-read kmers were generated.
#   3:26:46.452    14G / 22G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 651)   Subclustering statistics:
#   3:26:46.452    14G / 22G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 652)     Total singleton hamming clusters: 369076012. Among them 368863222 (99.9423%) are good
#   3:26:46.452    14G / 22G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 653)     Total singleton subclusters: 14754844. Among them 14754757 (99.9994%) are good
#   3:26:46.452    14G / 22G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 654)     Total non-singleton subcluster centers: 22415023. Among them 22373124 (99.8131%) are good
#   3:26:46.452    14G / 22G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 655)     Average size of non-trivial subcluster: 2.80414 kmers
#   3:26:46.452    14G / 22G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 656)     Average number of sub-clusters per non-singleton cluster: 1.39381
#   3:26:46.452    14G / 22G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 657)     Total solid k-mers: 405991103
#   3:26:46.452    14G / 22G   INFO   Hamming Subclustering    (kmer_cluster.cpp          : 658)     Substitution probabilities: [4,4]((0.950494,0.00928495,0.0294449,0.010776),(0.0105669,0.947135,0.0104638,0.0318343),(0.02955,0.00967173,0.949458,0.0113199),(0.0100066,0.0272995,0.0086045,0.954089))
#   3:26:46.887    14G / 22G   INFO    General                 (main.cpp                  : 178)   Finished clustering.
#   3:26:46.888    14G / 22G   INFO    General                 (main.cpp                  : 197)   Starting solid k-mers expansion in 1 threads.
#   3:48:00.665    14G / 22G   INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 0 produced 9653712 new k-mers.
#   4:07:51.868    14G / 22G   INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 1 produced 161467 new k-mers.
#   4:27:34.866    14G / 22G   INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 2 produced 2935 new k-mers.
#   4:47:11.524    14G / 22G   INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 3 produced 66 new k-mers.
#   5:06:48.687    14G / 22G   INFO    General                 (main.cpp                  : 218)   Solid k-mers iteration 4 produced 0 new k-mers.
#   5:06:48.687    14G / 22G   INFO    General                 (main.cpp                  : 222)   Solid k-mers finalized
#   5:06:48.687    14G / 22G   INFO    General                 (hammer_tools.cpp          : 222)   Starting read correction in 1 threads.
#   5:06:48.687    14G / 22G   INFO    General                 (hammer_tools.cpp          : 235)   Correcting pair of reads: /xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal/ERR2198703_1.fastq.gz and /xdisk/bhurwitz/virus_hunting/kolodisner/03_contam_removal/ERR2198703_2.fastq.gz
#   5:06:49.225    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 0 of 100000 reads.
#   5:06:55.293    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 0
#   5:06:55.451    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 0
#   5:06:55.965    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 1 of 100000 reads.
#   5:07:01.995    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 1
#   5:07:02.156    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 1
#   5:07:02.661    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 2 of 100000 reads.
#   5:07:08.754    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 2
#   5:07:08.915    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 2
#   5:07:09.428    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 3 of 100000 reads.
#   5:07:15.506    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 3
#   5:07:15.668    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 3
#   5:07:16.174    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 4 of 100000 reads.
#   5:07:22.272    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 4
#   5:07:22.434    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 4
#   5:07:22.949    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 5 of 100000 reads.
#   5:07:29.030    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 5
#   5:07:29.192    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 5
#   5:07:29.702    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 6 of 100000 reads.
#   5:07:35.849    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 6
#   5:07:36.011    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 6
#   5:07:36.523    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 7 of 100000 reads.
#   5:07:42.834    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 7
#   5:07:42.996    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 7
#   5:07:43.504    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 8 of 100000 reads.
#   5:07:49.591    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 8
#   5:07:49.753    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 8
#   5:07:50.266    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 9 of 100000 reads.
#   5:07:56.356    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 9
#   5:07:56.516    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 9
#   5:07:57.027    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 10 of 100000 reads.
#   5:08:03.124    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 10
#   5:08:03.285    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 10
#   5:08:03.798    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 11 of 100000 reads.
#   5:08:09.987    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 11
#   5:08:10.148    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 11
#   5:08:10.660    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 12 of 100000 reads.
#   5:08:16.752    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 12
#   5:08:16.912    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 12
#   5:08:17.426    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 13 of 100000 reads.
#   5:08:23.483    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 13
#   5:08:23.643    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 13
#   5:08:24.155    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 14 of 100000 reads.
#   5:08:30.237    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 14
#   5:08:30.398    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 14
#   5:08:30.913    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 15 of 100000 reads.
#   5:08:36.987    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 15
#   5:08:37.147    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 15
#   5:08:37.658    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 16 of 100000 reads.
#   5:08:43.757    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 16
#   5:08:43.917    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 16
#   5:08:44.433    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 17 of 100000 reads.
#   5:08:49.071    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 17
#   5:08:49.236    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 17
#   5:08:49.752    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 18 of 100000 reads.
#   5:08:54.487    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 18
#   5:08:54.651    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 18
#   5:08:55.170    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 19 of 100000 reads.
#   5:08:59.924    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 19
#   5:09:00.089    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 19
#   5:09:00.605    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 20 of 100000 reads.
#   5:09:05.315    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 20
#   5:09:05.480    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 20
#   5:09:06.000    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 21 of 100000 reads.
#   5:09:10.665    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 21
#   5:09:10.830    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 21
#   5:09:11.346    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 22 of 100000 reads.
#   5:09:16.006    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 22
#   5:09:16.170    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 22
#   5:09:16.690    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 23 of 100000 reads.
#   5:09:21.438    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 23
#   5:09:21.602    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 23
#   5:09:22.118    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 24 of 100000 reads.
#   5:09:26.756    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 24
#   5:09:26.921    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 24
#   5:09:27.441    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 25 of 100000 reads.
#   5:09:32.064    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 25
#   5:09:32.227    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 25
#   5:09:32.743    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 26 of 100000 reads.
#   5:09:37.375    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 26
#   5:09:37.539    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 26
#   5:09:38.059    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 27 of 100000 reads.
#   5:09:42.688    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 27
#   5:09:42.855    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 27
#   5:09:43.373    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 28 of 100000 reads.
#   5:09:48.023    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 28
#   5:09:48.190    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 28
#   5:09:48.711    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 29 of 100000 reads.
#   5:09:53.359    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 29
#   5:09:53.527    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 29
#   5:09:54.044    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 30 of 100000 reads.
#   5:09:58.776    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 30
#   5:09:58.943    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 30
#   5:09:59.462    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 31 of 100000 reads.
#   5:10:04.278    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 31
#   5:10:04.444    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 31
#   5:10:04.958    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 32 of 100000 reads.
#   5:10:09.729    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 32
#   5:10:09.897    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 32
#   5:10:10.416    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 33 of 100000 reads.
#   5:10:15.134    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 33
#   5:10:15.302    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 33
#   5:10:15.819    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 34 of 100000 reads.
#   5:10:20.495    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 34
#   5:10:20.662    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 34
#   5:10:21.180    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 35 of 100000 reads.
#   5:10:25.934    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 35
#   5:10:26.102    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 35
#   5:10:26.620    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 36 of 100000 reads.
#   5:10:31.273    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 36
#   5:10:31.441    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 36
#   5:10:31.964    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 37 of 100000 reads.
#   5:10:36.602    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 37
#   5:10:36.769    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 37
#   5:10:37.286    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 38 of 100000 reads.
#   5:10:41.930    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 38
#   5:10:42.097    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 38
#   5:10:42.620    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 39 of 100000 reads.
#   5:10:47.259    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 39
#   5:10:47.427    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 39
#   5:10:47.944    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 40 of 100000 reads.
#   5:10:52.589    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 40
#   5:10:52.756    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 40
#   5:10:53.274    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 41 of 100000 reads.
#   5:10:57.991    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 41
#   5:10:58.158    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 41
#   5:10:58.675    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 42 of 100000 reads.
#   5:11:03.378    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 42
#   5:11:03.545    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 42
#   5:11:04.065    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 43 of 100000 reads.
#   5:11:08.858    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 43
#   5:11:09.026    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 43
#   5:11:09.542    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 44 of 100000 reads.
#   5:11:14.452    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 44
#   5:11:14.909    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 44
#   5:11:15.428    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 45 of 100000 reads.
#   5:11:20.176    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 45
#   5:11:20.344    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 45
#   5:11:20.861    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 46 of 100000 reads.
#   5:11:25.508    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 46
#   5:11:25.675    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 46
#   5:11:26.195    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 47 of 100000 reads.
#   5:11:30.909    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 47
#   5:11:31.077    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 47
#   5:11:31.595    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 48 of 100000 reads.
#   5:11:36.265    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 48
#   5:11:36.432    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 48
#   5:11:36.953    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 49 of 100000 reads.
#   5:11:41.586    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 49
#   5:11:41.754    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 49
#   5:11:42.269    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 50 of 100000 reads.
#   5:11:46.920    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 50
#   5:11:47.088    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 50
#   5:11:47.609    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 51 of 100000 reads.
#   5:11:52.253    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 51
#   5:11:52.420    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 51
#   5:11:52.936    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 52 of 100000 reads.
#   5:11:57.581    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 52
#   5:11:57.749    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 52
#   5:11:58.269    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 53 of 100000 reads.
#   5:12:02.908    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 53
#   5:12:03.075    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 53
#   5:12:03.591    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 54 of 100000 reads.
#   5:12:08.231    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 54
#   5:12:08.399    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 54
#   5:12:08.918    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 55 of 100000 reads.
#   5:12:13.661    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 55
#   5:12:13.828    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 55
#   5:12:14.344    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 56 of 100000 reads.
#   5:12:19.084    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 56
#   5:12:19.252    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 56
#   5:12:19.773    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 57 of 100000 reads.
#   5:12:24.432    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 57
#   5:12:24.600    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 57
#   5:12:25.115    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 58 of 100000 reads.
#   5:12:29.779    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 58
#   5:12:29.947    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 58
#   5:12:30.466    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 59 of 100000 reads.
#   5:12:35.275    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 59
#   5:12:35.443    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 59
#   5:12:35.960    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 60 of 100000 reads.
#   5:12:40.615    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 60
#   5:12:40.782    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 60
#   5:12:41.301    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 61 of 100000 reads.
#   5:12:45.933    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 61
#   5:12:46.100    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 61
#   5:12:46.617    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 62 of 100000 reads.
#   5:12:51.269    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 62
#   5:12:51.437    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 62
#   5:12:51.956    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 63 of 100000 reads.
#   5:12:56.580    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 63
#   5:12:56.747    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 63
#   5:12:57.264    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 64 of 100000 reads.
#   5:13:01.911    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 64
#   5:13:02.079    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 64
#   5:13:02.601    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 65 of 100000 reads.
#   5:13:07.239    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 65
#   5:13:07.407    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 65
#   5:13:07.922    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 66 of 100000 reads.
#   5:13:12.616    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 66
#   5:13:12.784    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 66
#   5:13:13.303    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 67 of 100000 reads.
#   5:13:18.056    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 67
#   5:13:18.224    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 67
#   5:13:18.740    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 68 of 100000 reads.
#   5:13:23.440    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 68
#   5:13:23.608    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 68
#   5:13:24.128    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 69 of 100000 reads.
#   5:13:28.803    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 69
#   5:13:28.970    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 69
#   5:13:29.484    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 70 of 100000 reads.
#   5:13:34.180    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 70
#   5:13:34.348    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 70
#   5:13:34.867    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 71 of 100000 reads.
#   5:13:39.647    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 71
#   5:13:39.815    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 71
#   5:13:40.329    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 72 of 100000 reads.
#   5:13:44.998    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 72
#   5:13:45.297    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 72
#   5:13:45.817    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 73 of 100000 reads.
#   5:13:50.461    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 73
#   5:13:50.629    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 73
#   5:13:51.146    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 74 of 100000 reads.
#   5:13:55.801    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 74
#   5:13:55.968    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 74
#   5:13:56.488    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 75 of 100000 reads.
#   5:14:01.125    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 75
#   5:14:01.292    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 75
#   5:14:01.811    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 76 of 100000 reads.
#   5:14:06.455    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 76
#   5:14:06.622    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 76
#   5:14:07.141    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 77 of 100000 reads.
#   5:14:11.783    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 77
#   5:14:11.951    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 77
#   5:14:12.468    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 78 of 100000 reads.
#   5:14:17.109    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 78
#   5:14:17.276    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 78
#   5:14:17.796    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 79 of 100000 reads.
#   5:14:22.488    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 79
#   5:14:22.655    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 79
#   5:14:23.171    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 80 of 100000 reads.
#   5:14:27.836    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 80
#   5:14:28.003    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 80
#   5:14:28.523    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 81 of 100000 reads.
#   5:14:33.237    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 81
#   5:14:33.404    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 81
#   5:14:33.919    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 82 of 100000 reads.
#   5:14:38.612    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 82
#   5:14:38.779    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 82
#   5:14:39.294    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 83 of 100000 reads.
#   5:14:44.142    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 83
#   5:14:44.309    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 83
#   5:14:44.826    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 84 of 100000 reads.
#   5:14:49.498    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 84
#   5:14:49.664    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 84
#   5:14:50.185    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 85 of 100000 reads.
#   5:14:54.839    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 85
#   5:14:55.005    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 85
#   5:14:55.522    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 86 of 100000 reads.
#   5:15:00.162    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 86
#   5:15:00.329    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 86
#   5:15:00.850    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 87 of 100000 reads.
#   5:15:05.491    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 87
#   5:15:05.657    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 87
#   5:15:06.173    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 88 of 100000 reads.
#   5:15:10.823    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 88
#   5:15:10.989    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 88
#   5:15:11.508    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 89 of 100000 reads.
#   5:15:16.149    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 89
#   5:15:16.316    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 89
#   5:15:16.834    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 90 of 100000 reads.
#   5:15:21.473    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 90
#   5:15:21.639    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 90
#   5:15:22.156    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 91 of 100000 reads.
#   5:15:26.915    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 91
#   5:15:27.081    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 91
#   5:15:27.598    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 92 of 100000 reads.
#   5:15:32.275    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 92
#   5:15:32.441    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 92
#   5:15:32.959    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 93 of 100000 reads.
#   5:15:37.600    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 93
#   5:15:37.767    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 93
#   5:15:38.284    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 94 of 100000 reads.
#   5:15:42.998    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 94
#   5:15:43.165    14G / 22G   INFO    General                 (hammer_tools.cpp          : 187)   Written batch 94
#   5:15:43.681    14G / 22G   INFO    General                 (hammer_tools.cpp          : 170)   Prepared batch 95 of 100000 reads.
#   5:15:48.456    14G / 22G   INFO    General                 (hammer_tools.cpp          : 177)   Processed batch 95
# ...
#   1:25:02.028  3394M / 3964M INFO   PairInfoImprover         (pair_info_improver.hpp    : 104)   Paired info stats: missing = 1497; contradictional = 0
#   1:25:02.029  3394M / 3964M INFO    General                 (distance_estimation.cpp   : 104)   Filling scaffolding index
#   1:25:02.029  3394M / 3964M INFO   DistanceEstimator        (distance_estimation.hpp   : 116)   Using SMOOTHING distance estimator
#   1:25:06.710  3397M / 3964M INFO    General                 (distance_estimation.cpp   :  37)   Filtering info
#   1:25:06.711  3397M / 3964M INFO    General                 (pair_info_filters.hpp     : 242)   Start filtering; library index size: 733042
#   1:25:07.071  3413M / 3964M INFO    General                 (pair_info_filters.hpp     : 263)   Done filtering; library index size: 733042
#   1:25:07.072  3397M / 3964M INFO    General                 (distance_estimation.cpp   : 186)   Clearing raw paired index
#   1:25:07.288  3249M / 3964M INFO   StageManager             (stage.cpp                 : 185)   STAGE == Preliminary Repeat Resolving (id: repeat_resolving_preliminary)
#   1:25:07.331  3249M / 3964M INFO    General                 (repeat_resolving.cpp      :  74)   Setting up preliminary path extend settings
#   1:25:07.332  3249M / 3964M INFO    General                 (repeat_resolving.cpp      :  87)   Using Path-Extend repeat resolving
#   1:25:07.334  3249M / 3964M INFO    General                 (launcher.cpp              : 600)   ExSPAnder repeat resolving tool started
#   1:25:08.507  4610M / 5036M INFO    General                 (launcher.cpp              : 418)   Creating main extenders, unique edge length = 2000
#   1:25:08.509  4610M / 5036M INFO    General                 (extenders_logic.cpp       : 345)   Creating extender; library index size: 1155753
#   1:25:08.516  4646M / 5068M INFO    General                 (extenders_logic.cpp       : 345)   Creating extender; library index size: 1155753
#   1:25:08.679  4730M / 5162M INFO    General                 (extenders_logic.cpp       : 543)   Using 1 paired-end library
#   1:25:08.681  4730M / 5162M INFO    General                 (extenders_logic.cpp       : 544)   Using 1 paired-end scaffolding library
#   1:25:08.682  4730M / 5162M INFO    General                 (extenders_logic.cpp       : 545)   Using 0 single read libraries
#   1:25:08.684  4730M / 5162M INFO    General                 (launcher.cpp              : 447)   Total number of extenders is 3
#   1:25:08.686  4730M / 5162M INFO    General                 (path_extenders.cpp        :  36)   Processed 0 paths from 337321 (0%)
#   1:25:08.820  4738M / 5195M INFO    General                 (path_extenders.cpp        :  34)   Processed 128 paths from 337321 (0%)
#   1:25:08.949  4744M / 5197M INFO    General                 (path_extenders.cpp        :  34)   Processed 256 paths from 337321 (0%)
#   1:25:09.091  4751M / 5199M INFO    General                 (path_extenders.cpp        :  34)   Processed 512 paths from 337321 (0%)
#   1:25:09.248  4760M / 5199M INFO    General                 (path_extenders.cpp        :  34)   Processed 1024 paths from 337321 (0%)
#   1:25:09.463  4771M / 5211M INFO    General                 (path_extenders.cpp        :  34)   Processed 2048 paths from 337321 (0%)
#   1:25:09.691  4785M / 5223M INFO    General                 (path_extenders.cpp        :  34)   Processed 4096 paths from 337321 (1%)
#   1:25:10.000  4807M / 5241M INFO    General                 (path_extenders.cpp        :  34)   Processed 8192 paths from 337321 (2%)
#   1:25:10.448  4850M / 5287M INFO    General                 (path_extenders.cpp        :  34)   Processed 16384 paths from 337321 (4%)
#   1:25:11.104  4922M / 5368M INFO    General                 (path_extenders.cpp        :  34)   Processed 32768 paths from 337321 (9%)
#   1:25:11.142  4926M / 5372M INFO    General                 (path_extenders.cpp        :  36)   Processed 33733 paths from 337321 (10%)
#   1:25:12.095  5058M / 5507M INFO    General                 (path_extenders.cpp        :  34)   Processed 65536 paths from 337321 (19%)
#   1:25:12.144  5065M / 5513M INFO    General                 (path_extenders.cpp        :  36)   Processed 67466 paths from 337321 (20%)
#   1:25:12.986  5203M / 5649M INFO    General                 (path_extenders.cpp        :  36)   Processed 101199 paths from 337321 (30%)
#   1:25:13.538  5321M / 5763M INFO    General                 (path_extenders.cpp        :  34)   Processed 131072 paths from 337321 (38%)
#   1:25:13.604  5337M / 5779M INFO    General                 (path_extenders.cpp        :  36)   Processed 134932 paths from 337321 (40%)
#   1:25:14.141  5473M / 5919M INFO    General                 (path_extenders.cpp        :  36)   Processed 168665 paths from 337321 (50%)
#   1:25:14.596  5605M / 6047M INFO    General                 (path_extenders.cpp        :  36)   Processed 202398 paths from 337321 (60%)
#   1:25:15.053  5738M / 6179M INFO    General                 (path_extenders.cpp        :  36)   Processed 236131 paths from 337321 (70%)
#   1:25:15.561  5841M / 6283M INFO    General                 (path_extenders.cpp        :  34)   Processed 262144 paths from 337321 (77%)
#   1:25:15.714  5872M / 6313M INFO    General                 (path_extenders.cpp        :  36)   Processed 269864 paths from 337321 (80%)
#   1:25:17.626  6022M / 6463M INFO    General                 (path_extenders.cpp        :  36)   Processed 303597 paths from 337321 (90%)
#   1:25:18.605  6073M / 6519M INFO    General                 (launcher.cpp              : 250)   Finalizing paths
#   1:25:18.610  6073M / 6519M INFO    General                 (launcher.cpp              : 252)   Deduplicating paths
#   1:25:18.934  5998M / 6519M INFO    General                 (launcher.cpp              : 256)   Paths deduplicated
#   1:25:18.938  5998M / 6519M INFO    General                 (launcher.cpp              : 263)   Overlaps will not be removed
#   1:25:19.317  5999M / 6524M INFO    General                 (launcher.cpp              : 273)   Paths finalized
#   1:25:19.321  5999M / 6524M INFO    General                 (launcher.cpp              : 454)   Closing gaps in paths
#   1:25:20.308  7010M / 7461M INFO    General                 (launcher.cpp              : 484)   Gap closing completed
#   1:25:20.512  7062M / 7535M INFO    General                 (launcher.cpp              : 302)   Traversing tandem repeats
#   1:25:22.055  7062M / 7569M INFO    General                 (launcher.cpp              : 312)   Traversed 25 loops
#   1:25:22.059  7062M / 7569M INFO    General                 (launcher.cpp              : 250)   Finalizing paths
#   1:25:22.063  7062M / 7569M INFO    General                 (launcher.cpp              : 252)   Deduplicating paths
#   1:25:22.305  7062M / 7569M INFO    General                 (launcher.cpp              : 256)   Paths deduplicated
#   1:25:22.309  7062M / 7569M INFO    General                 (launcher.cpp              : 263)   Overlaps will not be removed
#   1:25:22.677  7062M / 7569M INFO    General                 (launcher.cpp              : 273)   Paths finalized
#   1:25:22.681  7062M / 7569M INFO    General                 (launcher.cpp              : 664)   ExSPAnder repeat resolving tool finished
#   1:25:23.651  4260M / 7569M INFO    General                 (repeat_resolving.cpp      :  93)   Restoring initial path extend settings
#   1:25:23.705  4260M / 7569M INFO   StageManager             (stage.cpp                 : 185)   STAGE == Contig Output (id: contig_output)
#   1:25:23.721  4260M / 7569M INFO    General                 (contig_output_stage.cpp   : 151)   Writing GFA graph to /xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly/out_spades/ERR2198703/K55/strain_graph.gfa
#   1:25:25.207  4260M / 7569M INFO    General                 (contig_output_stage.cpp   : 196)   Breaking scaffolds
#   1:25:28.618  5737M / 7569M INFO    General                 (contig_output_stage.cpp   :  98)   Outputting contigs to /xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly/out_spades/ERR2198703/K55/final_contigs.fasta
#   1:25:30.412  4260M / 7569M INFO   StageManager             (stage.cpp                 : 185)   STAGE == Second Phase Setup (id: second_phase_setup)
#   1:25:30.424  4260M / 7569M INFO    General                 (second_phase_setup.cpp    :  18)   Preparing second phase
#   1:25:31.083  2976M / 7569M INFO    General                 (second_phase_setup.cpp    :  26)   Moving preliminary contigs from /xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly/out_spades/ERR2198703/K55/final_contigs.fasta to /xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly/out_spades/ERR2198703/K55/first_pe_contigs.fasta
#   1:25:31.161  2976M / 7569M INFO    General                 (second_phase_setup.cpp    :  38)   Ready to run second phase
#   1:25:31.162  2976M / 7569M INFO   StageManager             (stage.cpp                 : 185)   STAGE == Simplification (id: simplification)
#   1:25:31.167  1278M / 7569M INFO    General                 (simplification.cpp        : 368)   Graph simplification started
#   1:25:31.168  1278M / 7569M INFO    General                 (graph_simplification.hpp  : 634)   Creating parallel br instance
#   1:25:31.168  1279M / 7569M INFO    General                 (simplification.cpp        : 373)   PROCEDURE == Simplification cycle, iteration 1
#   1:25:31.168  1279M / 7569M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Tip clipper
#   1:25:31.475  1279M / 7569M INFO   Simplification           (parallel_processing.hpp   : 170)   Tip clipper triggered 0 times
#   1:25:31.475  1279M / 7569M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Bulge remover
#   1:25:36.350  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 170)   Bulge remover triggered 18144 times
#   1:25:36.367  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Low coverage edge remover
#   1:25:36.592  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 170)   Low coverage edge remover triggered 0 times
#   1:25:36.593  1408M / 7569M INFO    General                 (simplification.cpp        : 373)   PROCEDURE == Simplification cycle, iteration 2
#   1:25:36.593  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Tip clipper
#   1:25:36.599  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 170)   Tip clipper triggered 13 times
#   1:25:36.599  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Bulge remover
#   1:25:36.599  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 170)   Bulge remover triggered 0 times
#   1:25:36.600  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Low coverage edge remover
#   1:25:36.600  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 170)   Low coverage edge remover triggered 0 times
#   1:25:36.600  1408M / 7569M INFO    General                 (simplification.cpp        : 373)   PROCEDURE == Simplification cycle, iteration 3
#   1:25:36.601  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Tip clipper
#   1:25:36.601  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 170)   Tip clipper triggered 0 times
#   1:25:36.601  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Bulge remover
#   1:25:36.602  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 170)   Bulge remover triggered 0 times
#   1:25:36.602  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Low coverage edge remover
#   1:25:36.602  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 170)   Low coverage edge remover triggered 0 times
#   1:25:36.603  1408M / 7569M INFO    General                 (simplification.cpp        : 373)   PROCEDURE == Simplification cycle, iteration 4
#   1:25:36.603  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Tip clipper
#   1:25:36.877  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 170)   Tip clipper triggered 0 times
#   1:25:36.878  1408M / 7569M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Bulge remover
#   1:25:37.121  1407M / 7569M INFO   Simplification           (parallel_processing.hpp   : 170)   Bulge remover triggered 4 times
#   1:25:37.121  1407M / 7569M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Low coverage edge remover
#   1:25:37.343  1407M / 7569M INFO   Simplification           (parallel_processing.hpp   : 170)   Low coverage edge remover triggered 0 times
#   1:25:37.344  1407M / 7569M INFO    General                 (simplification.cpp        : 373)   PROCEDURE == Simplification cycle, iteration 5
#   1:25:37.344  1407M / 7569M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Tip clipper
#   1:25:37.344  1407M / 7569M INFO   Simplification           (parallel_processing.hpp   : 170)   Tip clipper triggered 0 times
#   1:25:37.345  1407M / 7569M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Bulge remover
#   1:25:37.345  1407M / 7569M INFO   Simplification           (parallel_processing.hpp   : 170)   Bulge remover triggered 0 times
#   1:25:37.345  1407M / 7569M INFO   Simplification           (parallel_processing.hpp   : 167)   Running Low coverage edge remover
#   1:25:37.346  1407M / 7569M INFO   Simplification           (parallel_processing.hpp   : 170)   Low coverage edge remover triggered 0 times
#   1:25:37.430  1407M / 7569M INFO   StageManager             (stage.cpp                 : 185)   STAGE == Gap Closer (id: late_gapcloser)
#   1:25:37.434  1416M / 7569M INFO    General                 (edge_index.hpp            : 113)   Size of edge index entries: 12/8
#   1:25:37.827  1426M / 7569M INFO    General                 (gap_closer.cpp            : 101)   Total edges in tip neighborhood: 452756 out of 567866, length: 210802707
#   1:25:37.851  1430M / 7569M INFO    General                 (edge_index.hpp            : 167)   Using small index (max_id = 12104172)
#   1:25:43.260  1430M / 7569M INFO   K-mer Index Building     (kmer_index_builder.hpp    : 395)   Building perfect hash indices
#   1:26:37.866  1516M / 7569M INFO   K-mer Index Building     (kmer_index_builder.hpp    : 431)   Index built. Total 118018257 kmers, 85269042 bytes occupied (5.78006 bits per kmer).
#   1:26:38.097  2421M / 7569M INFO    General                 (edge_index_builders.hpp   : 265)   Collecting edge information from graph, this takes a while.
#   1:27:28.351  2418M / 7569M INFO    General                 (sequence_mapper_notifier.h:  77)   Processed 200000 reads
#   1:27:39.913  2419M / 7569M INFO    General                 (sequence_mapper_notifier.h:  77)   Processed 400000 reads
#   1:27:51.479  2420M / 7569M INFO    General                 (sequence_mapper_notifier.h:  77)   Processed 600000 reads
#   1:28:02.947  2421M / 7569M INFO    General                 (sequence_mapper_notifier.h:  77)   Processed 800000 reads
#   1:28:14.484  2421M / 7569M INFO    General                 (sequence_mapper_notifier.h:  77)   Processed 1000000 reads
#   1:28:26.043  2422M / 7569M INFO    General                 (sequence_mapper_notifier.h:  77)   Processed 1200000 reads
#   1:29:23.733  2424M / 7569M INFO    General                 (sequence_mapper_notifier.h:  77)   Processed 2200000 reads
#   1:31:19.057  2428M / 7569M INFO    General                 (sequence_mapper_notifier.h:  77)   Processed 4200000 reads
#   1:35:20.956  2438M / 7569M INFO    General                 (sequence_mapper_notifier.h:  77)   Processed 8400000 reads

# %%
# Do you see a contigs file?
# !ls $work_dir/out_spades/*
# Out:
# /xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly/out_spades/ERR2198703:
# K21  configs	   input_dataset.yaml  pipeline_state	spades.log
# K33  corrected	   misc		       run_spades.sh	tmp
# K55  dataset.info  params.txt	       run_spades.yaml
#
# /xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly/out_spades/ERR2198704:
# K21  configs	   input_dataset.yaml  pipeline_state	spades.log
# K33  corrected	   misc		       run_spades.sh	tmp
# K55  dataset.info  params.txt	       run_spades.yaml
#
# /xdisk/bhurwitz/virus_hunting/kolodisner/04_assembly/out_spades/ERR2198705:
# K21  configs	   input_dataset.yaml  pipeline_state	spades.log
# K33  corrected	   misc		       run_spades.sh	tmp
# K55  dataset.info  params.txt	       run_spades.yaml

# %% [markdown]
# Great job! You should now have assemblies from metaspades. You can kick off the assembly below with megahit without disrupting your work from above. Go for it!

# %% [markdown]
# ## Final Step
# Copy your notebook to the current working directory

# %%
cp ~/04_assembly.ipynb $work_dir
